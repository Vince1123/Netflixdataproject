# %% [markdown]
# 1.Reading the Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Importing required libraries
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset (ensure that the file name and path are correct)
df = pd.read_csv('/content/NFLX 3.csv')

# Display the first 5 rows of the dataset
print(df.head())
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 1  2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2  2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 3  2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 4  2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
#
#      Volume
# 0  11896100
# 1  12595800
# 2   8981500
# 3   9306700
# 4  16906900

# %%
# !ls
# Out:
#  drive	'NFLX 3.csv'   sample_data

# %%
import pandas as pd
import numpy as np

Netflixdata=pd.read_csv('/content/NFLX 3.csv' , encoding='latin')

print('Shape before deleting duplicate values:', Netflixdata.shape)
output = df.drop_duplicates()

Netflixdata.head(10)
# Out:
# Shape before deleting duplicate values: (1009, 7)
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 1  2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2  2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 3  2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 4  2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
# 5  2018-02-12  252.139999  259.149994  249.000000  257.950012  257.950012
# 6  2018-02-13  257.290009  261.410004  254.699997  258.269989  258.269989
# 7  2018-02-14  260.470001  269.880005  260.329987  266.000000  266.000000
# 8  2018-02-15  270.029999  280.500000  267.630005  280.269989  280.269989
# 9  2018-02-16  278.730011  281.959991  275.690002  278.519989  278.519989
#
#      Volume
# 0  11896100
# 1  12595800
# 2   8981500
# 3   9306700
# 4  16906900
# 5   8534900
# ...

# %% [markdown]
# 2.Problem Statement Defenition

# %% [markdown]
# This Project is based on the Netflix stock price prediction Available from Kaggle
# https://www.kaggle.com/datasets/jainilcoder/netflix-stock-price-prediction/data
#
# *   It contains 1009 data consisting of the following Date, Open, high, low, Close, Adj Close and volume.
# *   My task is to create a project that predicts Netflic price stock.
# *   When solving this problem i will take a step by step approach to create a program that predicts stock price using different python programs such as panda and numpy.

# %% [markdown]
# 3.Target Variable Identification

# %% [markdown]
# My target variable is closed price. This is due to closed price usually representing the final trading price of a stock at the end of a trading day.
#
# Featured variables include: Date, Open, High, Low, Adj Close and volume.

# %% [markdown]
# 4.Visualising the distribution of Target variable

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('/content/NFLX 3.csv', encoding='latin')


# Plotting the distribution of the target variable 'Close'

plt.hist(data['Close'])

# Display the plot
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# 5.Data exploration at basic level

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1009 entries, 0 to 1008
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1009 non-null   object
#  1   Open       1009 non-null   float64
#  2   High       1009 non-null   float64
#  3   Low        1009 non-null   float64
#  4   Close      1009 non-null   float64
#  5   Adj Close  1009 non-null   float64
#  6   Volume     1009 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 55.3+ KB
# None

# %%
print(data.describe())
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1009.000000  1009.000000  1009.000000  1009.000000  1009.000000
# mean    412.374044   425.320703   412.374044   419.000733   419.000733
# std     107.555867   109.262960   107.555867   108.289999   108.289999
# min     231.229996   250.649994   231.229996   233.880005   233.880005
# 25%     326.000000   336.299988   326.000000   331.619995   331.619995
# 50%     370.880005   383.010010   370.880005   378.670013   378.670013
# 75%     502.529999   515.630005   502.529999   509.079987   509.079987
# max     686.090027   700.989990   686.090027   691.690002   691.690002
#
#              Volume
# count  1.009000e+03
# mean   7.570685e+06
# std    5.465535e+06
# min    1.144000e+06
# 25%    4.091900e+06
# 50%    5.934500e+06
# 75%    9.322400e+06
# max    5.890430e+07

# %%
data = pd.read_csv('/content/NFLX 3.csv', encoding='latin')

data.nunique()
# Out:
# Date         1009
# Open          976
# High          983
# Low           989
# Close         988
# Adj Close     988
# Volume       1005
# dtype: int64

# %% [markdown]
# 6.Identifying and Rejecting useless columns

# %%
import pandas as pd

Netflixdata = pd.read_csv('/content/NFLX 3.csv', encoding='latin')

# Use Netflixdata instead of data
print(Netflixdata.columns)

output = Netflixdata.drop(columns={'Date', 'Adj Close'})

print(output)
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')
#             Open        High         Low       Close    Volume
# 0     262.000000  267.899994  250.029999  254.259995  11896100
# 1     247.699997  266.700012  245.000000  265.720001  12595800
# 2     266.579987  272.450012  264.329987  264.559998   8981500
# 3     267.079987  267.619995  250.000000  250.100006   9306700
# 4     253.850006  255.800003  236.110001  249.470001  16906900
# ...          ...         ...         ...         ...       ...
# 1004  401.970001  427.700012  398.200012  427.140015  20047500
# 1005  432.959991  458.480011  425.540009  457.130005  22542300
# 1006  448.250000  451.980011  426.480011  429.480011  14346000
# 1007  421.440002  429.260010  404.279999  405.600006   9905200
# 1008  407.309998  412.769989  396.640015  410.170013   7782400
#
# [1009 rows x 5 columns]

# %% [markdown]
# 7.Visual Exploratory Data Analysis
# of data with Histogram and
# Barcharts

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Define the data
data = {  # Removed extra indentation here
    'Date': [
        '2018-02-05', '2018-02-06', '2018-02-07', '2018-02-08',
        '2018-02-09', '2018-02-12', '2018-02-13', '2018-02-14', '2018-02-15'
    ],
    'Open': [
        262.000000, 247.699997, 266.579987, 267.079987,
        253.850006, 252.139999, 257.290009, 260.470001, 270.029999
    ],
    'High': [
        267.899994, 266.700012, 272.450012, 267.619995,
        255.800003, 259.149994, 261.410004, 269.880005, 280.500000
    ],
    'Low': [
        250.029999, 245.000000, 264.329987, 250.000000,
        236.110001, 249.000000, 254.699997, 260.329987, 267.630005
    ],
    'Close': [
        254.259995, 265.720001, 264.559998, 250.100006,
        249.470001, 257.950012, 258.269989, 266.000000, 280.269989
    ]
}  # Removed extra indentation here

# Create a DataFrame
df = pd.DataFrame(data)

# Convert 'Date' to datetime format
df['Date'] = pd.to_datetime(df['Date'])

# Set up the plot style
sns.set(style="whitegrid")

# Create a figure with 2x2 subplots
plt.figure(figsize=(14, 10))

# Plot bar chart for 'Open'
plt.subplot(2, 2, 1)
sns.barplot(x=df['Date'], y=df['Open'], color='green')
plt.title('Opening Prices')
plt.xlabel('Date')
plt.ylabel('Open Price')
plt.xticks(rotation=45)

# Plot bar chart for 'High'
plt.subplot(2, 2, 2)
sns.barplot(x=df['Date'], y=df['High'], color='blue')
plt.title('High Prices')
plt.xlabel('Date')
plt.ylabel('High Price')
plt.xticks(rotation=45)

# Plot bar chart for 'Low'
plt.subplot(2, 2, 3)
sns.barplot(x=df['Date'], y=df['Low'], color='red')
plt.title('Low Prices')
plt.xlabel

# Plot bar chart for 'Close'
plt.subplot(2, 2, 4)
sns.barplot(x=df['Date'], y=df['Close'], color='black')
plt.title('Closing Prices')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.xticks(rotation=45)

# Adjust layout
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load data
data = pd.read_csv('/content/NFLX 3.csv')

# Set up the plot style
sns.set(style="whitegrid")

# Create a figure with 2x2 subplots
plt.figure(figsize=(14, 10))

# Plot histogram for 'High'
plt.subplot(2, 2, 1)
sns.histplot(data['High'], kde=True, color='blue')

# Plot histogram for 'Open'
plt.subplot(2, 2, 2)
sns.histplot(data['Open'], kde=True, color='green')


# Plot histogram for 'Low'
plt.subplot(2, 2, 3)
sns.histplot(data['Low'], kde=True, color='red')

# Plot histogram for 'Close'
plt.subplot(2, 2, 4)
sns.histplot(data['Close'], kde=True, color='black')

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# 8.Feature Selection based on data
# distribution

# %%
import pandas as pd

# Assuming 'NFLX 3.csv' is in the correct location and contains the data
Netflixdata = pd.read_csv('/content/NFLX 3.csv', encoding='latin')

continuousCols = ['Open', 'High', 'Low', 'Close', 'Volume']

# Use 'corr' instead of 'carr' to calculate the correlation matrix
CorrelationData = Netflixdata[continuousCols].corr()
print(CorrelationData)
# Out:
#             Open      High       Low     Close    Volume
# Open    1.000000  0.998605  0.998508  0.996812 -0.415838
# High    0.998605  1.000000  0.998203  0.998551 -0.400699
# Low     0.998508  0.998203  1.000000  0.998544 -0.432116
# Close   0.996812  0.998551  0.998544  1.000000 -0.413362
# Volume -0.415838 -0.400699 -0.432116 -0.413362  1.000000

# %%
CorrelationData['High'].sort_values(ascending=False)
# Out:
# High      1.000000
# Open      0.998605
# Close     0.998551
# Low       0.998203
# Volume   -0.400699
# Name: High, dtype: float64

# %% [markdown]
# 9.Removal of outliers and missing
# values

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# Load data
data = pd.read_csv('/content/NFLX 3.csv')

# Set up the plot style
sns.set(style="whitegrid")

# Display initial data info
print("Initial Data Info:")
print(data.info())

# Check for missing values
print("\nMissing Values:")
print(data.isnull().sum())

# Handling Missing Values
# Replace 'Kilometers_Driven' with the actual numeric column name from your dataset
numeric_column = 'Close'  # Update with the correct column name

# Fill missing values with the mean (for numerical columns)
data[numeric_column] = data[numeric_column].fillna(data[numeric_column].mean())

# Fill missing values with a specific value (e.g., 'Unknown' for categorical columns)
# Replace 'Categorical_Column' with the actual categorical column name
data['Open'] = data['Low'].fillna('Unknown')  # Update with the correct column name


# Z-Score Method
z_scores = stats.zscore(data[[numeric_column]])
abs_z_scores = np.abs(z_scores)
threshold = 3
data_no_outliers_z = data[(abs_z_scores < threshold).all(axis=1)]



# Visualization of Outliers
plt.figure(figsize=(14, 8))

# Box plot for the numeric column
plt.subplot(1, 2, 1)
sns.boxplot(x=data[numeric_column])
plt.title(f'Boxplot of {numeric_column}')


plt.tight_layout()
plt.show()
# Out:
# ERROR:root:Unexpected exception finding object shape
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/google/colab/_debugpy_repr.py", line 54, in get_shape
#     shape = getattr(obj, 'shape', None)
#   File "/usr/local/lib/python3.10/dist-packages/werkzeug/local.py", line 318, in __get__
#     obj = instance._get_current_object()
#   File "/usr/local/lib/python3.10/dist-packages/werkzeug/local.py", line 519, in _get_current_object
#     raise RuntimeError(unbound_message) from None
# RuntimeError: Working outside of request context.
#
# This typically means that you attempted to use functionality that needed
# an active HTTP request. Consult the documentation on testing for
# information about how to avoid this problem.
# Initial Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1009 entries, 0 to 1008
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
# ...

# %%
Netflixdata = pd.read_csv('/content/NFLX 3.csv') # Define Netflixdata here

ContinuousCols=['Open', 'High', 'Low', 'Volume']

for predictor in ContinuousCols:
    # Indent the code inside the loop
    Netflixdata.plot.scatter(x=predictor, y='Close', figsize=(10,5), title=predictor)

# %% [markdown]
# 10.Visual and Statistic Correlation
# analysis for selection of best
# features

# %%
# Defining a function to find the statistical relationship with all the categorical variables
def FunctionAnova(inpData, TargetVariable, CategoricalPredictorList):
    from scipy.stats import f_oneway

    # Creating an empty list of final selected predictors
    SelectedPredictors=[]

    print('##### ANOVA Results ##### \n')
    for predictor in CategoricalPredictorList:
        CategoryGroupLists=inpData.groupby(predictor)[TargetVariable].apply(list)
        AnovaResults = f_oneway(*CategoryGroupLists)

        # If the ANOVA P-Value is <0.05, that means we reject H0
        if (AnovaResults[1] < 0.05):
            print(predictor, 'is correlated with', TargetVariable, '| P-Value:', AnovaResults[1])
            SelectedPredictors.append(predictor)
        else:
            print(predictor, 'is NOT correlated with', TargetVariable, '| P-Value:', AnovaResults[1])

    return(SelectedPredictors)

#Calling the function to check which categorical variables are correlated with target
CategoricalPredictorList=['Open', 'Low']
FunctionAnova(inpData=Netflixdata,
              TargetVariable='Close',
              CategoricalPredictorList=CategoricalPredictorList)
# Out:
# ##### ANOVA Results #####
#
# Open is correlated with Close | P-Value: 7.2308149687975e-34
# Low is correlated with Close | P-Value: 5.816258457006985e-21
# ['Open', 'Low']

# %%
SelectedColumns= ['Open', 'High', 'Low', 'Close']

DataforML=Netflixdata[SelectedColumns]
DataforML.head()
# Out:
#          Open        High         Low       Close
# 0  262.000000  267.899994  250.029999  254.259995
# 1  247.699997  266.700012  245.000000  265.720001
# 2  266.579987  272.450012  264.329987  264.559998
# 3  267.079987  267.619995  250.000000  250.100006
# 4  253.850006  255.800003  236.110001  249.470001

# %%
# Saving this final data subset for reference during deployment
DataforML.to_pickle('DataForML.pkl') # Changed 'DataForML' to 'DataforML' to match the variable name

# %%
# Defining the list of selected columns
SelectedColumns = ['Open', 'High', 'Low', 'Close']

# Treating all the nominal variables at once using dummy variables
DataforML_Numeric = pd.get_dummies(Netflixdata[SelectedColumns])

# Adding Target Variable to the data
DataforML_Numeric['Close'] = Netflixdata['Close']

# Printing sample rows
DataforML_Numeric.head()
# Out:
#          Open        High         Low       Close
# 0  262.000000  267.899994  250.029999  254.259995
# 1  247.699997  266.700012  245.000000  265.720001
# 2  266.579987  272.450012  264.329987  264.559998
# 3  267.079987  267.619995  250.000000  250.100006
# 4  253.850006  255.800003  236.110001  249.470001

# %% [markdown]
# 11.Data Conversion to numeric
# values for machine
# learning/predictive analysis

# %%
# Printing all the column names for our reference
DataforML_Numeric.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close'], dtype='object')

# %%
#Separate Target Variable and Predictor Variables
TargetVariable='Close'
Predictors = DataforML_Numeric.columns[DataforML_Numeric.columns != TargetVariable].tolist() # Changed 'DataForML_Numeric' to 'DataforML_Numeric'

X=DataforML_Numeric[Predictors].values # Changed 'DataForML_Numeric' to 'DataforML_Numeric'
y=DataforML_Numeric[TargetVariable].values # Changed 'DataForML_Numeric' to 'DataforML_Numeric'

# Split the data into training and testing set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=428)

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# Initialize the MinMaxScaler
scaler = MinMaxScaler()

# Fit the scaler and transform the features (X)
X_scaled = scaler.fit_transform(X)

# Split the data into training and testing sets (30% for testing, 70% for training)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

# %%
# Sanity check for the sampled data
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (706, 3)
# (706,)
# (303, 3)
# (303,)

# %% [markdown]
# 12.Training/Testing Sampling and K-fold cross validation

# %%
#Multiple Linear Regression
from sklearn.linear_model import LinearRegression
RegModel = LinearRegression()

# Printing all the parameters of Linear regression
print(RegModel)

# Creating the model on Training Data
LREG=RegModel.fit(X_train,y_train)
prediction=LREG.predict(X_test)

from sklearn import metrics
# Measuring Goodness of fit in Training data
print('R2 Value:',metrics.r2_score(y_train, LREG.predict(X_train)))

###########################################################################
print('\n##### Model Validation and Accuracy Calculations ##########')

# Printing some sample values of prediction
TestingDataResults=pd.DataFrame(data=X_test, columns=Predictors)
TestingDataResults[TargetVariable]=y_test
TestingDataResults[('Predicted'+TargetVariable)]=np.round(prediction)

# Printing sample prediction values
print(TestingDataResults.head())

# Calculating the error for each row
# Use the correct TargetVariable instead of 'MEDV'
TestingDataResults['APE']=100 * ((abs(
  TestingDataResults[TargetVariable]-TestingDataResults['Predicted'+TargetVariable]))/TestingDataResults[TargetVariable])

MAPE=np.mean(TestingDataResults['APE'])
MedianMAPE=np.median(TestingDataResults['APE'])

Accuracy =100 - MAPE
MedianAccuracy=100- MedianMAPE
print('Mean Accuracy on test data:', Accuracy) # Can be negative sometimes due to outlier
print('Median Accuracy on test data:', MedianAccuracy)

# Defining a custom function to calculate accuracy
# Make sure there are no zeros in the Target variable if you are using MAPE
def Accuracy_Score(orig,pred):
    MAPE = np.mean(100 * (np.abs(orig-pred)/orig))
    #print('#'*70,'Accuracy:', 100-MAPE)
    return(100-MAPE)

# Custom Scoring MAPE calculation
from sklearn.metrics import make_scorer
custom_Scoring=make_scorer(Accuracy_Score, greater_is_better=True)

# Importing cross validation function from sklearn
from sklearn.model_selection import cross_val_score

# Running 10-Fold Cross validation on a given algorithm
# Passing full data X and y because the K-fold will split the data and automatically choose train/test
Accuracy_Values=cross_val_score(RegModel, X , y, cv=10, scoring=custom_Scoring)
print('\nAccuracy values for 10-fold Cross Validation:\n',Accuracy_Values)
print('\nFinal Average Accuracy of the model:', round(Accuracy_Values.mean(),2))
# Out:
# LinearRegression()
# R2 Value: 0.9986731542285744
#
# ##### Model Validation and Accuracy Calculations ##########
#        Open      High       Low       Close  PredictedClose
# 0  0.577471  0.576875  0.587917  509.640015           508.0
# 1  0.592304  0.572101  0.561601  494.730011           493.0
# 2  0.596449  0.585891  0.589962  500.859985           507.0
# 3  0.330279  0.303482  0.322451  380.070007           381.0
# 4  0.195188  0.166985  0.182474  315.100006           319.0
# Mean Accuracy on test data: 99.3029073385015
# Median Accuracy on test data: 99.47124720149543
#
# Accuracy values for 10-fold Cross Validation:
#  [99.21860151 99.21910542 99.19755296 99.4083654  99.47040237 98.9092798
#  99.20776329 99.40785386 99.62149833 99.22984505]
#
# Final Average Accuracy of the model: 99.29

# %%
# Decision Trees (Multiple if-else statements!)
from sklearn.tree import DecisionTreeRegressor
RegModel = DecisionTreeRegressor(max_depth=5,criterion='friedman_mse')
# Good Range of Max_depth = 2 to 20

# Printing all the parameters of Decision Tree
print(RegModel)

# Creating the model on Training Data
DT=RegModel.fit(X_train,y_train)
prediction=DT.predict(X_test)

from sklearn import metrics
# Measuring Goodness of fit in Training data
print('R2 Value:',metrics.r2_score(y_train, DT.predict(X_train)))

# Plotting the feature importance for Top 10 most important columns
# %matplotlib inline
feature_importances = pd.Series(DT.feature_importances_, index=Predictors)
feature_importances.nlargest(10).plot(kind='barh')

###########################################################################
print('\n##### Model Validation and Accuracy Calculations ##########')

# Printing some sample values of prediction
TestingDataResults=pd.DataFrame(data=X_test, columns=Predictors)
TestingDataResults[TargetVariable]=y_test
TestingDataResults[('Predicted'+TargetVariable)]=np.round(prediction)

# Printing sample prediction values
print(TestingDataResults.head())

# Calculating the error for each row
TestingDataResults['APE']=100 * ((abs(
  TestingDataResults['Close']-TestingDataResults['PredictedClose']))/TestingDataResults['Close'])

MAPE=np.mean(TestingDataResults['APE'])
MedianMAPE=np.median(TestingDataResults['APE'])

Accuracy =100 - MAPE
MedianAccuracy=100- MedianMAPE
print('Mean Accuracy on test data:', Accuracy) # Can be negative sometimes due to outlier
print('Median Accuracy on test data:', MedianAccuracy)

# Defining a custom function to calculate accuracy
def Accuracy_Score(orig,pred):
    MAPE = np.mean(100 * (np.abs(orig-pred)/orig))
    #print('#'*70,'Accuracy:', 100-MAPE)
    return(100-MAPE)

# Custom Scoring MAPE calculation
from sklearn.metrics import make_scorer
custom_Scoring=make_scorer(Accuracy_Score, greater_is_better=True)

# Importing cross validation function from sklearn
from sklearn.model_selection import cross_val_score

# Running 10-Fold Cross validation on a given algorithm
Accuracy_Values=cross_val_score(RegModel, X , y, cv=10, scoring=custom_Scoring)
print('\nAccuracy values for 10-fold Cross Validation:\n',Accuracy_Values)
print('\nFinal Average Accuracy of the model:', round(Accuracy_Values.mean(),2))
# Out:
# DecisionTreeRegressor(criterion='friedman_mse', max_depth=5)
# R2 Value: 0.9976613969339876
#
# ##### Model Validation and Accuracy Calculations ##########
#        Open      High       Low       Close  PredictedClose
# 0  0.577471  0.576875  0.587917  509.640015           509.0
# 1  0.592304  0.572101  0.561601  494.730011           496.0
# 2  0.596449  0.585891  0.589962  500.859985           509.0
# 3  0.330279  0.303482  0.322451  380.070007           386.0
# 4  0.195188  0.166985  0.182474  315.100006           322.0
# Mean Accuracy on test data: 98.56869716791199
# Median Accuracy on test data: 98.8354057430968
#
# Accuracy values for 10-fold Cross Validation:
#  [98.40322063 98.50561057 98.48597259 98.84648187 98.33407053 97.24234762
#  97.95457369 98.81150986 98.98729668 95.69681323]
#
# Final Average Accuracy of the model: 98.13

# %%
# Decision Trees (Multiple if-else statements!)
from sklearn.tree import DecisionTreeRegressor
RegModel = DecisionTreeRegressor(max_depth=5,criterion='friedman_mse')
# Good Range of Max_depth = 2 to 20
# Load libraries
from IPython.display import Image
from sklearn import tree
import pydotplus

# Fit the model to your training data (assuming X_train and y_train are defined)
RegModel.fit(X_train, y_train)  # Fit the model before visualizing

# Create DOT data
dot_data = tree.export_graphviz(RegModel, out_file=None,
                                feature_names=Predictors,
                                class_names=None)  # Set class_names to None for regression

# printing the rules
#print(dot_data)

# Draw graph
graph = pydotplus.graph_from_dot_data(dot_data)

# Show graph
Image(graph.create_png(), width=3000,height=300)

# %%
# Random Forest (Bagging of multiple Decision Trees)
from sklearn.ensemble import RandomForestRegressor
RegModel = RandomForestRegressor(max_depth=4, n_estimators=400,criterion='friedman_mse')
# Good range for max_depth: 2-10 and n_estimators: 100-1000

# Printing all the parameters of Random Forest
print(RegModel)

# Creating the model on Training Data
RF=RegModel.fit(X_train,y_train)
prediction=RF.predict(X_test)

from sklearn import metrics
# Measuring Goodness of fit in Training data
print('R2 Value:',metrics.r2_score(y_train, RF.predict(X_train)))

# Plotting the feature importance for Top 10 most important columns
# %matplotlib inline
feature_importances = pd.Series(RF.feature_importances_, index=Predictors)
feature_importances.nlargest(10).plot(kind='barh')


print('\n##### Model Validation and Accuracy Calculations ##########')

# Printing some sample values of prediction
TestingDataResults=pd.DataFrame(data=X_test, columns=Predictors)
TestingDataResults[TargetVariable]=y_test
TestingDataResults[('Predicted'+TargetVariable)]=np.round(prediction)

# Printing sample prediction values
print(TestingDataResults.head())

# Calculating the error for each row
# Use the correct TargetVariable here:
TestingDataResults['APE']=100 * ((abs(
  TestingDataResults[TargetVariable]-TestingDataResults['Predicted'+ TargetVariable]))/TestingDataResults[TargetVariable])

MAPE=np.mean(TestingDataResults['APE'])
MedianMAPE=np.median(TestingDataResults['APE'])

Accuracy =100 - MAPE
MedianAccuracy=100- MedianMAPE
print('Mean Accuracy on test data:', Accuracy) # Can be negative sometimes due to outlier
print('Median Accuracy on test data:', MedianAccuracy)


# Defining a custom function to calculate accuracy
# Make sure there are no zeros in the Target variable if you are using MAPE
def Accuracy_Score(orig,pred):
    MAPE = np.mean(100 * (np.abs(orig-pred)/orig))
    #print('#'*70,'Accuracy:', 100-MAPE)
    return(100-MAPE)

# Custom Scoring MAPE calculation
from sklearn.metrics import make_scorer
custom_Scoring=make_scorer(Accuracy_Score, greater_is_better=True)

# Importing cross validation function from sklearn
from sklearn.model_selection import cross_val_score

# Running 10-Fold Cross validation on a given algorithm
# Passing full data X and y because the K-fold will split the data and automatically choose train/test
Accuracy_Values=cross_val_score(RegModel, X , y, cv=10, scoring=custom_Scoring)
print('\nAccuracy values for 10-fold Cross Validation:\n',Accuracy_Values)
print('\nFinal Average Accuracy of the model:', round(Accuracy_Values.mean(),2))
# Out:
# RandomForestRegressor(criterion='friedman_mse', max_depth=4, n_estimators=400)
# R2 Value: 0.9971939305523058
#
# ##### Model Validation and Accuracy Calculations ##########
#        Open      High       Low       Close  PredictedClose
# 0  0.577471  0.576875  0.587917  509.640015           501.0
# 1  0.592304  0.572101  0.561601  494.730011           497.0
# 2  0.596449  0.585891  0.589962  500.859985           504.0
# 3  0.330279  0.303482  0.322451  380.070007           383.0
# 4  0.195188  0.166985  0.182474  315.100006           322.0
# Mean Accuracy on test data: 98.7504995973464
# Median Accuracy on test data: 99.00620041834864
#
# Accuracy values for 10-fold Cross Validation:
#  [98.45887021 98.37802423 98.37386867 98.84442097 98.62968157 97.58503452
#  97.785014   98.58092289 99.02345001 94.62120377]
#
# Final Average Accuracy of the model: 98.03

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn import tree
from IPython.display import Image
import pydotplus

# Train the RandomForestRegressor model
# Ensure your model is trained using the fit() method before accessing estimators_
RegModel = RandomForestRegressor(n_estimators=100, max_depth=3)
RegModel.fit(X_train, y_train)  # Ensure you have already fit the model

# Get the 6th Decision Tree from the trained RandomForest model
# Ensure the model has enough trees (at least 6 in this case)
dot_data = tree.export_graphviz(RegModel.estimators_[5], out_file=None, feature_names=Predictors, filled=True, rounded=True)

# Create the graph using pydotplus
graph = pydotplus.graph_from_dot_data(dot_data)

# Show the graph as PNG
Image(graph.create_png(), width=2000, height=200)

# %%
from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn import metrics
import pandas as pd
import numpy as np
from sklearn.metrics import make_scorer
from sklearn.model_selection import cross_val_score

# Initialize and train AdaBoost model
DTR = DecisionTreeRegressor(max_depth=3)
RegModel = AdaBoostRegressor(n_estimators=100, base_estimator=DTR, learning_rate=0.04)
RegModel.fit(X_train, y_train)

# Predict on test data
prediction = RegModel.predict(X_test)

# R2 score for training data
print('R2 Value:', metrics.r2_score(y_train, RegModel.predict(X_train)))

# Feature importance plot
feature_importances = pd.Series(RegModel.feature_importances_, index=Predictors[:X_train.shape[1]])
feature_importances.nlargest(10).plot(kind='barh')

# Model validation and accuracy calculations
TestingDataResults = pd.DataFrame(X_test, columns=Predictors[:X_test.shape[1]])
TestingDataResults[TargetVariable] = y_test
TestingDataResults['Predicted' + TargetVariable] = np.round(prediction)

# Error and accuracy calculations
TestingDataResults['APE'] = 100 * abs(TestingDataResults[TargetVariable] - TestingDataResults['Predicted' + TargetVariable]) / TestingDataResults[TargetVariable]
MAPE = np.mean(TestingDataResults['APE'])
MedianMAPE = np.median(TestingDataResults['APE'])

print('Mean Accuracy:', 100 - MAPE)
print('Median Accuracy:', 100 - MedianMAPE)

# Custom accuracy function
def Accuracy_Score(orig, pred):
    return 100 - np.mean(100 * abs(orig - pred) / orig)

# Cross-validation with custom scoring
custom_scorer = make_scorer(Accuracy_Score, greater_is_better=True)
Accuracy_Values = cross_val_score(RegModel, X, y, cv=10, scoring=custom_scorer)

print('10-fold Cross-Validation Accuracy:', Accuracy_Values)
print('Final Average Accuracy:', round(Accuracy_Values.mean(), 2))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:156: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# R2 Value: 0.9894762241454779
# Mean Accuracy: 97.77376616103635
# Median Accuracy: 98.0902537247164
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:156: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:156: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:156: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# ...

# %%
from xgboost import XGBRegressor
from sklearn import metrics
from sklearn.metrics import make_scorer
from sklearn.model_selection import cross_val_score
import pandas as pd
import numpy as np

# Initialize XGBoost model
RegModel = XGBRegressor(max_depth=2, learning_rate=0.1, n_estimators=1000)

# Train the model
RegModel.fit(X_train, y_train)

# Make predictions
prediction = RegModel.predict(X_test)

# R2 Score on training data
print('R2 Value:', metrics.r2_score(y_train, RegModel.predict(X_train)))

# Feature importance plot for the top 10 features
feature_importances = pd.Series(RegModel.feature_importances_, index=Predictors[:X_test.shape[1]])
feature_importances.nlargest(10).plot(kind='barh')

# Prepare test data results
TestingDataResults = pd.DataFrame(X_test, columns=Predictors[:X_test.shape[1]])
TestingDataResults[TargetVariable] = y_test
TestingDataResults['Predicted' + TargetVariable] = np.round(prediction)

# Display sample results
print(TestingDataResults.head())

# Calculate error and accuracy
TestingDataResults['APE'] = 100 * abs(TestingDataResults[TargetVariable] - TestingDataResults['Predicted' + TargetVariable]) / TestingDataResults[TargetVariable]

MAPE = np.mean(TestingDataResults['APE'])
MedianMAPE = np.median(TestingDataResults['APE'])

print('Mean Accuracy:', 100 - MAPE)
print('Median Accuracy:', 100 - MedianMAPE)

# Custom accuracy function
def Accuracy_Score(orig, pred):
    return 100 - np.mean(100 * abs(orig - pred) / orig)

# Cross-validation
custom_scorer = make_scorer(Accuracy_Score, greater_is_better=True)
Accuracy_Values = cross_val_score(RegModel, X, y, cv=10, scoring=custom_scorer)
print('10-fold Cross-Validation Accuracy:', Accuracy_Values)
print('Final Average Accuracy:', round(Accuracy_Values.mean(), 2))
# Out:
# R2 Value: 0.9995434001336165
#        Open      High       Low       Close  PredictedClose
# 0  0.577471  0.576875  0.587917  509.640015           508.0
# 1  0.592304  0.572101  0.561601  494.730011           493.0
# 2  0.596449  0.585891  0.589962  500.859985           510.0
# 3  0.330279  0.303482  0.322451  380.070007           386.0
# 4  0.195188  0.166985  0.182474  315.100006           314.0
# Mean Accuracy: 99.0735366085426
# Median Accuracy: 99.34123847167325
# 10-fold Cross-Validation Accuracy: [98.92809133 98.92258095 98.9963492  99.31086522 99.12503009 98.04559908
#  98.86405587 99.12300896 99.47586872 95.57050986]
# Final Average Accuracy: 98.64

# %%
#Plotting a single Decision tree out of XGBoost
from xgboost import plot_tree
import matplotlib.pyplot as plt

# Initialize and train the XGBoost model (replace with your actual model parameters)
XGB = XGBRegressor(max_depth=3, learning_rate=0.1, n_estimators=100)
XGB.fit(X_train, y_train) # Assuming X_train and y_train are defined

fig, ax = plt.subplots(figsize=(20, 8))
plot_tree(XGB, num_trees=10, ax=ax)
plt.show() # Display the plot

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn import metrics
from sklearn.model_selection import cross_val_score
import pandas as pd
import numpy as np
from sklearn.metrics import make_scorer

# Initialize and train the KNN model
RegModel = KNeighborsRegressor(n_neighbors=3)
RegModel.fit(X_train, y_train)

# Predict on test data
prediction = RegModel.predict(X_test)

# R2 score for training data
print('R2 Value:', metrics.r2_score(y_train, RegModel.predict(X_train)))

# Prepare test data results
TestingDataResults = pd.DataFrame(X_test, columns=Predictors[:X_test.shape[1]])
TestingDataResults[TargetVariable] = y_test
TestingDataResults['Predicted' + TargetVariable] = np.round(prediction)

# Display sample predictions
print(TestingDataResults.head())

# Calculate error and accuracy
TestingDataResults['APE'] = 100 * abs(TestingDataResults[TargetVariable] - TestingDataResults['Predicted' + TargetVariable]) / TestingDataResults[TargetVariable]
MAPE = np.mean(TestingDataResults['APE'])
MedianMAPE = np.median(TestingDataResults['APE'])

print('Mean Accuracy:', 100 - MAPE)
print('Median Accuracy:', 100 - MedianMAPE)

# Custom accuracy function
def Accuracy_Score(orig, pred):
    return 100 - np.mean(100 * abs(orig - pred) / orig)

# Cross-validation with custom scoring
custom_scorer = make_scorer(Accuracy_Score, greater_is_better=True)
Accuracy_Values = cross_val_score(RegModel, X, y, cv=10, scoring=custom_scorer)

print('10-fold Cross-Validation Accuracy:', Accuracy_Values)
print('Final Average Accuracy:', round(Accuracy_Values.mean(), 2))
# Out:
# R2 Value: 0.9989790942951331
#        Open      High       Low       Close  PredictedClose
# 0  0.577471  0.576875  0.587917  509.640015           505.0
# 1  0.592304  0.572101  0.561601  494.730011           488.0
# 2  0.596449  0.585891  0.589962  500.859985           507.0
# 3  0.330279  0.303482  0.322451  380.070007           382.0
# 4  0.195188  0.166985  0.182474  315.100006           321.0
# Mean Accuracy: 99.05814068358532
# Median Accuracy: 99.31442221288626
# 10-fold Cross-Validation Accuracy: [98.96036708 99.05941097 98.97269318 99.27796124 99.1382778  98.36592285
#  98.83590812 99.26551811 99.45550666 95.94679425]
# Final Average Accuracy: 98.73

# %% [markdown]
# 13.Investigating multiple Regression algorithms

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn import metrics
from sklearn.model_selection import cross_val_score
import pandas as pd
import numpy as np

# Initialize and train the KNN model
RegModel = KNeighborsRegressor(n_neighbors=3)
RegModel.fit(X_train, y_train)

# Predict on test data
prediction = RegModel.predict(X_test)

# R2 score for training data
print('R2 Value:', metrics.r2_score(y_train, RegModel.predict(X_train)))

# Prepare test data results
TestingDataResults = pd.DataFrame(X_test, columns=Predictors[:X_test.shape[1]])
TestingDataResults[TargetVariable] = y_test
TestingDataResults['Predicted' + TargetVariable] = np.round(prediction)

# Display sample predictions
print(TestingDataResults.head())

# Calculate error and accuracy
TestingDataResults['APE'] = 100 * abs(TestingDataResults[TargetVariable] - TestingDataResults['Predicted' + TargetVariable]) / TestingDataResults[TargetVariable]
MAPE = np.mean(TestingDataResults['APE'])
MedianMAPE = np.median(TestingDataResults['APE'])

print('Mean Accuracy:', 100 - MAPE)
print('Median Accuracy:', 100 - MedianMAPE)

# Custom accuracy function
def Accuracy_Score(orig, pred):
    return 100 - np.mean(100 * abs(orig - pred) / orig)

# Cross-validation with custom scoring
custom_scorer = make_scorer(Accuracy_Score, greater_is_better=True)
Accuracy_Values = cross_val_score(RegModel, X, y, cv=10, scoring=custom_scorer)

print('10-fold Cross-Validation Accuracy:', Accuracy_Values)
print('Final Average Accuracy:', round(Accuracy_Values.mean(), 2))
# Out:
# R2 Value: 0.9989790942951331
#        Open      High       Low       Close  PredictedClose
# 0  0.577471  0.576875  0.587917  509.640015           505.0
# 1  0.592304  0.572101  0.561601  494.730011           488.0
# 2  0.596449  0.585891  0.589962  500.859985           507.0
# 3  0.330279  0.303482  0.322451  380.070007           382.0
# 4  0.195188  0.166985  0.182474  315.100006           321.0
# Mean Accuracy: 99.05814068358532
# Median Accuracy: 99.31442221288626
# 10-fold Cross-Validation Accuracy: [98.96036708 99.05941097 98.97269318 99.27796124 99.1382778  98.36592285
#  98.83590812 99.26551811 99.45550666 95.94679425]
# Final Average Accuracy: 98.73

# %%
# Separate Target Variable and Predictor Variables
TargetVariable='Close'

# Selecting the final set of predictors for the deployment
# Based on the variable importance charts of multiple algorithms above
Predictors=['Open', 'High', 'Low']

# Load your data (replace 'your_data.csv' with your actual file)
import pandas as pd
DataForML_Numeric = pd.read_csv('/content/NFLX 3.csv')

X=DataForML_Numeric[Predictors].values
y=DataForML_Numeric[TargetVariable].values

### Sandardization of data ###
from sklearn.preprocessing import StandardScaler, MinMaxScaler
# Choose either standardization or Normalization
# On this data Min Max Normalization produced better results

# Choose between standardization and MinMAx normalization
#PredictorScaler=StandardScaler()
PredictorScaler=MinMaxScaler()

# Storing the fit object for later reference
PredictorScalerFit=PredictorScaler.fit(X)

# Generating the standardized values of X
X=PredictorScalerFit.transform(X)

print(X.shape)
print(y.shape)
# Out:
# (1009, 3)
# (1009,)

# %%
# Importing cross validation function from sklearn
from sklearn.model_selection import cross_val_score

# choose from different tunable hyper parameters
from xgboost import XGBRegressor
RegModel=XGBRegressor(max_depth=2,
                      learning_rate=0.1,
                      n_estimators=1000,
                      objective='reg:linear',
                      booster='gbtree')

# Running 10-Fold Cross validation on a given algorithm
# Passing full data X and y because the K-fold will split the data and automatically choose train/test
Accuracy_Values=cross_val_score(RegModel, X , y, cv=10, scoring=custom_Scoring)
print('\nAccuracy values for 10-fold Cross Validation:\n',Accuracy_Values)
print('\nFinal Average Accuracy of the model:', round(Accuracy_Values.mean(),2))
# Out:
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:07:44] WARNING: /workspace/src/objective/regression_obj.cu:227: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:07:45] WARNING: /workspace/src/objective/regression_obj.cu:227: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:07:46] WARNING: /workspace/src/objective/regression_obj.cu:227: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:07:47] WARNING: /workspace/src/objective/regression_obj.cu:227: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# ...

# %%
# Training the model on 100% Data available
Final_XGB_Model=RegModel.fit(X,y)
# Out:
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:15:28] WARNING: /workspace/src/objective/regression_obj.cu:227: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)

# %%
import pickle
import os

# Saving the Python objects as serialized files can be done using pickle library
# Here let us save the Final model
with open('Final_XGB_Model.pkl', 'wb') as fileWriteStream:
    pickle.dump(Final_XGB_Model, fileWriteStream)
    # Don't forget to close the filestream!
    fileWriteStream.close()

print('pickle file of Predictive Model is saved at Location:',os.getcwd())
# Out:
# pickle file of Predictive Model is saved at Location: /content

# %% [markdown]
# 14.Selection of the best Model

# %%
import pandas as pd
import pickle

def FunctionPredictResult(InputData):
    # Load training data and model
    DataForML = pd.read_pickle('DataForML.pkl')
    with open('Final_XGB_Model.pkl', 'rb') as file:
        PredictionModel = pickle.load(file)

    # Concatenate new data with training data and create dummies
    InputData = pd.concat([InputData, DataForML], ignore_index=True)
    InputData = pd.get_dummies(InputData)

    # Prepare input data for prediction
    Predictors = ['Open', 'High', 'Low']
    X = InputData[Predictors].values[-len(InputData):]

    # Standardize the data
    X = PredictorScalerFit.transform(X)

    # Generate and return predictions
    Prediction = PredictionModel.predict(X)
    return pd.DataFrame(Prediction, columns=['Prediction'])

# %%
# Sample new data
NewSampleData = pd.DataFrame(data=[[4.98, 6.575, 15.3], [4.98, 3.2, 10.3]],
                             columns=['Open', 'High', 'Low'])

print(NewSampleData)

# Predict using the function
FunctionPredictResult(InputData=NewSampleData)
# Out:
#    Open   High   Low
# 0  4.98  6.575  15.3
# 1  4.98  3.200  10.3
#       Prediction
# 0     248.021103
# 1     248.021103
# 2     254.637924
# 3     264.014038
# 4     266.278442
# ...          ...
# 1006  420.016876
# 1007  451.019836
# 1008  435.700043
# 1009  411.660065
# 1010  409.584625
#
# [1011 rows x 1 columns]

# %% [markdown]
# 15.Deployment of the best model in
# production

# %%
from flask import Flask, request, jsonify
import pickle
import pandas as pd
import numpy

# %%
from flask import Flask, request, jsonify

app = Flask(__name__)

@app.route('/prediction_api', methods=["GET"])
def prediction_api():
    try:
        # Getting the paramters from API call
        Open_value = float(request.args.get('Open'))
        High_value=float(request.args.get('High'))
        Low_value=float(request.args.get('Low'))

        # Calling the funtion to get predictions
        prediction_from_api=FunctionGeneratePrediction(
                                                       inp_Open=Open_value,
                                                       inp_High=High_value,
                                                       inp_Low=Low_value
                                                )

        return (prediction_from_api)

    except Exception as e:
        return('Something is not right!:'+str(e))

# %%
import os
if __name__ =="__main__":

    # Hosting the API in localhost
    app.run(host='127.0.0.1', port=9000, threaded=True, debug=True, use_reloader=False)
    # Interrupt kernel to stop the API
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:9000
# INFO:werkzeug:Press CTRL+C to quit

# %%
import tkinter as tk
from tkinter import messagebox
from tkinter import ttk
import pandas as pd
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor
from sklearn.preprocessing import LabelEncoder

class NetflixPricePredictionApp:
    def __init__(self, master):
        self.master = master
        self.master.title('Netflix Price Prediction')
        self.data = pd.read_csv('/Users/user/Downloads/NFLX 2.csv')

        # Convert categorical variables into numerical variables if necessary
        categorical_cols = self.data.select_dtypes(include=['object']).columns
        le = LabelEncoder()
        for col in categorical_cols:
            self.data[col] = le.fit_transform(self.data[col])

        self.entries = []

        self.X = self.data.drop('Close', axis=1).values
        self.y = self.data['Close'].values

        self.X_train, self.X_test, self.y_train, self.y_test = train_test_split(self.X, self.y, test_size=0.2, random_state=42)

        self.model = XGBRegressor()
        self.model.fit(self.X_train, self.y_train)

        self.create_widgets()

    def create_widgets(self):
        columns = self.data.columns[:-1]  # All columns except the target 'Close'
        for i, column in enumerate(columns):
            label = tk.Label(self.master, text=column + ': ')
            label.grid(row=i, column=0)
            if self.data[column].dtype in [int, float]:
                slider = ttk.Scale(self.master, from_=self.data[column].min(), to=self.data[column].max(), orient="horizontal")
                slider.grid(row=i, column=1)
                current_val_label = tk.Label(self.master, text='0.0')
                current_val_label.grid(row=i, column=2)
                def update_label(slider, label):
                    def inner(val):
                        label.config(text=f'{slider.get():.2f}')
                    return inner
                slider.config(command=update_label(slider, current_val_label))
                self.entries.append(slider)
            else:
                entry = tk.Entry(self.master)
                entry.grid(row=i, column=1)
                self.entries.append(entry)

        predict_button = tk.Button(self.master, text='Predict Price', command=self.predict_price)
        predict_button.grid(row=len(columns), columnspan=3)

    def predict_price(self):
        inputs = [float(entry.get()) if isinstance(entry, tk.Entry) else float(entry.get()) for entry in self.entries]
        price = self.model.predict([inputs])
        messagebox.showinfo('Predicted Price', f'The predicted Netflix stock price is ${price[0]:.2f}')

if __name__ == '__main__':
    root = tk.Tk()
    app = NetflixPricePredictionApp(root)
    root.mainloop()
